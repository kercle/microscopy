# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy as sp
import PIL
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook

from microscopy.connection import Http
from microscopy.zscan import ZScanRepository
from microscopy.focus_stacking import FocusStacking

# %%
zscan_repo = ZScanRepository(Http("microscope-rpi", 3000))

# %%
fs = FocusStacking.from_zscan_thumbnails(zscan_repo.select(2), 512)
PIL.Image.fromarray(fs.condense(progress_iter=tqdm_notebook))
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x384>
