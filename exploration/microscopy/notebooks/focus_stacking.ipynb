# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from microscopy.connection import Http
from microscopy.zscan import ZScanRepository

# %%
zscan_repo = ZScanRepository(Http("microscope-rpi", 3000))

# %%
zscan = zscan_repo.select(0)
zscan.thumbnail(0, 512)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>
